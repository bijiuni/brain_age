# %%
# !nvidia-smi
# Out:
# Wed Mar 21 06:58:54 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 390.30                 Driver Version: 390.30                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    64W / 250W |  15607MiB / 16280MiB |     98%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from tensorflow.python.tools.inspect_checkpoint import print_tensors_in_checkpoint_file
print_tensors_in_checkpoint_file(file_name='FYP_epoch_20', tensor_name='',all_tensors=True)
# Out:
# tensor_name:  W_conv1
# [[[[[-0.1573344  -0.03152147 -0.1378381  -0.12883142 -0.0879017
#       0.0502804  -0.009509   -0.07865405]]
#
#    [[-0.04339223 -0.08107416  0.08860546  0.14137378 -0.09679033
#       0.07891706  0.04917991 -0.10462344]]
#
#    [[ 0.02211518 -0.09896498  0.01008162  0.0576935  -0.02438524
#       0.02187121  0.13334723  0.14012067]]]
#
#
#   [[[-0.05676761  0.11588363  0.13139746  0.01872188 -0.05482317
#      -0.03700646  0.11396202  0.00503394]]
#
#    [[ 0.05631465 -0.00096008  0.05337147  0.02764735 -0.11869221
#      -0.04315837  0.05452404  0.06942765]]
#
#    [[ 0.00382942 -0.09938388 -0.10911264 -0.14511172  0.02669821
#       0.06825311  0.07946973  0.06121062]]]
#
#
#   [[[-0.06554986  0.10490943 -0.07350835 -0.1477202  -0.02663041
#      -0.07650061 -0.01049598 -0.14313032]]
#
#    [[ 0.10265248 -0.11946152 -0.1346457   0.05727597 -0.11377186
#       0.04837636 -0.08786671 -0.00230703]]
#
# ...
